# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
df = pd.read_csv("https://raw.githubusercontent.com/freeCodeCamp/boilerplate-sea-level-predictor/master/epa-sea-level.csv")
df.head()
# Out:
#    Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0  1880                  0.000000          -0.952756           0.952756
# 1  1881                  0.220472          -0.732283           1.173228
# 2  1882                 -0.440945          -1.346457           0.464567
# 3  1883                 -0.232283          -1.129921           0.665354
# 4  1884                  0.590551          -0.283465           1.464567
#
#    NOAA Adjusted Sea Level
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
plt.subplots(figsize=(10,5))
plt.scatter(df['Year'], df['CSIRO Adjusted Sea Level'])
# Create first line of best fit

lin1 = linregress(df['Year'], df['CSIRO Adjusted Sea Level'])
plt.plot(np.arange(df['Year'].min(),2051,1),(np.arange(df['Year'].min(),2051,1)*lin1.slope + lin1.intercept))
# Create second line of best fit
df_2000 = df[df['Year'] >= 2000]
  
lin2 = linregress(df_2000['Year'], df_2000['CSIRO Adjusted Sea Level'])

plt.plot(np.arange(df_2000['Year'].min(),2051,1),(np.arange(df_2000['Year'].min(),2051,1)*lin2.slope + lin2.intercept))

# Add labels and title
  
plt.title("Rise in Sea Level")
plt.xlabel("Year")
plt.ylabel("Sea Level (inches)")
plt.show
# Out:
# <function matplotlib.pyplot.show>
